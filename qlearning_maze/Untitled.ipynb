# %%
import random
import numpy as np

# %%
actions = ['u','r','d','l']
qline = {'u':1.2, 'r':-2.1, 'd':-24.5, 'l':27}

# %%
qline.values()

# %%
actions[np.argmax(list(qline.values()))]

# %%
np.argmax(qline.values())

# %%
np.argmax(list(qline.values()))

# %%
max(qline, key=qline.get)

# %%
probs = [round(i*0.1, 1) for i in range(1,11)]
for i in range(10):
    print(random.choice(probs))

# %%
nS = range(4)
actions = ['u', 'r', 'd', 'l']
Qtable = {}
for s in nS:
    if s not in Qtable:
        Qtable[s] = {a:0.0 for a in actions}
print(Qtable)

# %%
Qtable[0].get

# %%
a = [random.choice(range(1, 100000))/100000 for i in range(100)]
cnt=0
for i in a:
    if i < 0.5:
        cnt+=1
print(cnt)

# %%
1/10000

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
print(a.astype(str))
# Out:
# ['1' '2' '3']

# %%
a = (1,2)
','.join([str(i) for i in a])
# Out:
# '1,2'

# %%
a = [1,2,3,4]
','.join([str(i) for i in a])
# Out:
# '1,2,3,4'

# %%
import math
for update_times in range(100*500):
    if update_times % 500 == 0:
        a = math.sqrt((update_times+1000)/1000)
        print(1.0 / a, a)

# %%
b=0
for i in range(40*500):
    a = 1.0/math.log(i+100,100)
    if a < 0.5:
        i -= b
        a = 1.0 - (1.0/(1+math.e**(-(i/200))))
    else:
        b=i
        a = 1.0/math.log(i+100,100)
        
    if i % 100 == 0:
        print(i, a)
# Out:
# 0 1.0
# 100 0.8691759793521874
# 200 0.8073888172367006
# 300 0.768621786840241
# 400 0.7410234262651711
# 500 0.7199032089141345
# 600 0.702963473269265
# 700 0.6889211181746088
# 800 0.6769924925288455
# 900 0.6666666666666667
# 1000 0.6575934800395407
# 1100 0.649523311616411
# 1200 0.6422724416352604
# 1300 0.6357020367001189
# 1400 0.6297048280012717
# 1500 0.6241963505817849
# 1600 0.6191089996082335
# 1700 0.6143878882227496
# 1800 0.6099878927830338
# 1900 0.6058715015092473
# 2000 0.602007219442202
# 2100 0.5983683665968955
# 2200 0.594932159162909
# 2300 0.5916789978449035
# 2400 0.588591910067779
# 2500 0.5856561080303607
# 2600 0.5828586350681452
# 2700 0.5801880800983356
# 2800 0.5776343451023352
# 2900 0.5751884543241927
# 3000 0.5728423965732311
# 3100 0.5705889940146422
# 3200 0.568421792317643
# 3300 0.5663349681484364
# 3400 0.564323250843976
# 3500 0.5623818557528477
# 3600 0.5605064272320409
# 3700 0.5586929896796455
# 3800 0.5569379052904468
# ...

# %%
def xxx(x):
    return (1.0 - math.e**(-x))**2

# %%
print(xxx(10))
# Out:
# 0.9999092022016286

# %%
for i in range(20*500):
    if i % 100 == 0:
        a = 1.0 - (1.0/(1+math.e**(-(i/1000))))
        print(i, a)
# Out:
# 0 0.5
# 100 0.47502081252106
# 200 0.45016600268752205
# 300 0.42555748318834097
# 400 0.401312339887548
# 500 0.3775406687981454
# 600 0.3543436937742046
# 700 0.33181222783183395
# 800 0.3100255188723875
# 900 0.2890504973749961
# 1000 0.2689414213699951
# 1100 0.2497398944048823
# 1200 0.23147521650098246
# 1300 0.2141650169574414
# 1400 0.1978161114414183
# 1500 0.18242552380635635
# 1600 0.16798161486607555
# 1700 0.15446526508353475
# 1800 0.1418510649004877
# 1900 0.13010847436299788
# 2000 0.11920292202211769
# 2100 0.10909682119561293
# 2200 0.0997504891196852
# 2300 0.09112296101485617
# 2400 0.08317269649392234
# 2500 0.07585818002124345
# 2600 0.06913842034334694
# 2700 0.0629733560569965
# 2800 0.057324175898868734
# 2900 0.052153563078417675
# 3000 0.04742587317756686
# 3100 0.04310725494108614
# 3200 0.039165722796764335
# 3300 0.03557118927263614
# 3400 0.03229546469845057
# 3500 0.02931223075135636
# 3600 0.026596993576865957
# 3700 0.024127021417669203
# ...
